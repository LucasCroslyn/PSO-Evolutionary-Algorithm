# %%
import SingleFunctions

# %%
SingleFunctions.singleObj(-1, 1, -500, 500, 500, 500, False)
# Out:
# gen	evals	avg    	std    	min    	max
# 0  	500  	848.817	283.216	78.5508	1592.02
# 1  	500  	847.61 	284.114	79.4975	1585.32
# 2  	500  	846.386	285.051	76.7019	1578.18
# 3  	500  	845.148	286.022	74.2103	1570.61
# 4  	500  	843.886	287.001	72.0254	1562.61
# 5  	500  	842.574	288.026	70.1497	1557.89
# 6  	500  	841.163	289.076	68.5855	1555.83
# 7  	500  	839.731	290.115	67.335 	1554.64
# 8  	500  	838.354	291.211	66.4002	1558.23
# 9  	500  	836.91 	292.34 	65.7829	1561.38
# 10 	500  	835.513	293.414	65.4847	1564.09
# 11 	500  	834.115	294.36 	65.5072	1566.35
# 12 	500  	832.572	295.433	66.6606	1568.17
# 13 	500  	831.119	296.389	66.2507	1569.55
# 14 	500  	829.605	297.356	60.4723	1570.49
# 15 	500  	828.208	298.398	55.0106	1570.99
# 16 	500  	826.671	299.465	49.8684	1571.04
# 17 	500  	824.959	300.435	44.5053	1570.66
# 18 	500  	823.375	301.56 	38.4176	1569.83
# 19 	500  	821.709	302.744	32.8042	1570.68
# 20 	500  	819.909	303.808	27.669 	1578.24
# ...

# %%
import MultiFunctions

# %%
MultiFunctions.multiObj(-0.5, 0.5, -5, 5, 500, 500, False)
# Out:
# gen	evals	avg1 	std1   	min1    	max1   	avg2   	std2   	min2  	max2
# 0  	500  	139.3	115.168	0.174521	685.431	36.9067	14.9699	1.2609	80.691
# 1  	500  	109.632	77.4657	0.403984	394.656	32.3162	12.4357	1.51245	69.1829
# 2  	500  	99.0006	61.9335	0.410827	271.743	29.7604	12.0272	1.50338	64.5891
# 3  	500  	101.935	55.9549	0.243577	218.919	26.1535	10.7403	2.05471	55.0727
# 4  	500  	108.501	50.7637	1.71993 	191.839	25.8745	10.6388	2.17502	52.4872
# 5  	500  	116.155	46.726 	6.8001  	189.59 	23.506 	10.2007	0.705378	54.3534
# 6  	500  	116.144	47.4777	3.8752  	201.209	24.0409	10.2667	0.703845	49.4248
# 7  	500  	116.344	48.5332	8.45088 	194.957	23.4537	10.2441	1.28738 	48.5615
# 8  	500  	116.847	47.384 	10.2199 	184.039	23.5952	10.4555	2.07879 	47.9402
# 9  	500  	116.919	46.6748	3.87275 	181.596	23.0166	10.1039	1.09029 	46.2321
# 10 	500  	115.168	48.4709	4.19817 	200.79 	23.9811	10.5689	1.02611 	47.5249
# 11 	500  	114.196	48.6562	10.1503 	183.05 	23.2727	9.86139	1.94127 	47.7591
# ...
